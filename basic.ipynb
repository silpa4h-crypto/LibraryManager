# %% [markdown]
# <a href="https://colab.research.google.com/github/silpa4h-crypto/LibraryManager/blob/main/basic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hai welcome to the class")

# %%
print ("silpa")
print ("kseb")

# %%
print("silpa,kseb")

# %%
print("silpa,2018")

# %%
name= "silpa"
company="kseb"
year= 2018
print(name,company,year)

# %%
print(f"{name} is working in {company} since {year}")
print("{} is working in {} since {}".format(name,company,year))

# %%
snack="cookies"
print(f"I love eating {snack}")

# %%
type(name)

# %%
type(year)

# %%
weight= 74
type(weight)

# %%
input("what is your name?")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-2316418192.py in <cell line: 0>()
# ----> 1 input("what is your name?")
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
# ...

# %%
my_name =input("what is your name?")
print(my_name)

# %%
income=float(input("enter your salary"))
expenses=float(input("enter your expenses"))
savings=income-expenses
print(savings)

# %%
month_1=12000
month_2=6000
month_3=8500
month_4=9600
totalsale=month_1+month_2+month_3+month_4
avgsale=totalsale/4
print(avgsale)

# %%
principal =50000
rate =4
time =3
si_interest =principal*rate*time/100
total_amount =principal+si_interest
print(si_interest)
print(total_amount)

# %%
name ="silpa"
surname = "sasikumar"
fullname= name + surname
print(fullname)

# %%
my_string ="i am learning python"
my_string

# %%
my_string[0]

# %%
my_string[-5]

# %%
# slicing
my_string[0:10]

# %%
# slicing
my_string[0:13]

# %%
#slicing
my_string[14:20]

# %%
len(my_string)

# %%
# strip()
email = "silPA4h@gmail.com"
len(email)

# %%
email1 = email.strip()
email1

# %%
len(email1)

# %%
email1.lower()

# %%
email.upper()

# %%
email1.capitalize()

# %%
email1.swapcase()

# %%
my_string = "I Love Python , Python is easy"
my_string.count("P")

# %%
my_string = ("I love Python ")
new_str = new_str.replace("python","Java")

# %%
my_list =["car" ,"bike", "bus" , "train"]
my_list

# %%
my_tuple =("car" ,"bike", "bus" , "train")
my_tuple

# %%
x=25
y=10

print(x%y)

# %%
print(x//y)

# %%
2**3

# %%
a=10
b=3
print(a**b)

# %%
age=25

print(age>=18)

# %%
age=25

print(age==18)

# %%
age=25

print(age==30)

# %%
age=25

print(age!=18)

# %%
order_quantity=120
max_order=200
print(order_quantity >max_order)

# %%
user="admin"
pw="1234"
print(user=="admin" and pw=="4534")

# %%
user="admin"
pw="1234"
print(user=="admin" or pw=="4534")

# %%
min_salary=50000
credit_score=650
customer_salary=45000
customer_credit=540
print (customer_salary>=min_salary and customer_credit>=credit_score)

# %%
min_salary=50000
credit_score=650
customer_salary=75000
customer_score=840
print (customer_salary>=min_salary and customer_score>=credit_score)

# %%
stock=50
print(stock)

# %%
stock=50
stock += 10
stock = stock + 10
print(stock)

# %%
stock-=15
print(stock)

# %%
stock=55
stock*= 2
print(stock)

# %%
a=25
b=10
d=25
c=a
print(a is b)

# %%
print(a==b)

# %%
print("p" in "Python")

# %%
print(c is a)

# %%
print(c)

# %%
print(a==d)

# %%
groceries=["milk" ,"bread" , "egg" ,"butter"]
type(groceries)
# Out:
# list

# %%
print("grocery list:",groceries)
# Out:
# grocery list: ['milk', 'bread', 'egg', 'butter']

# %%
groceries[0]
# Out:
# 'milk'

# %%
len(groceries)
# Out:
# 4

# %%
groceries[3:]
# Out:
# ['butter']

# %%
groceries[1:4]
# Out:
# ['bread', 'egg', 'butter']

# %%
groceries[2:4]
# Out:
# ['egg', 'butter']

# %%
new_list = ["biscuits" ,"chips"]
gro_list=groceries + new_list
gro_list
# Out:
# ['milk', 'bread', 'egg', 'butter', 'biscuits', 'chips']

# %%
#append()
gro_list.append("coffee")
gro_list
# Out:
# ['milk', 'bread', 'egg', 'butter', 'biscuits', 'chips', 'coffee']

# %%
gro_list.insert(2,"curd")
gro_list
# Out:
# ['milk', 'bread', 'curd', 'egg', 'butter', 'biscuits', 'chips', 'coffee']

# %%
new_list2= ["potatoes","onions","bread"]
gro_list.extend(new_list2)
gro_list
# Out:
# ['milk',
#  'bread',
#  'curd',
#  'egg',
#  'butter',
#  'biscuits',
#  'chips',
#  'coffee',
#  'potatoes',
#  'onions',
#  'bread']

# %%
gro_list.count("bread")
# Out:
# 2

# %%
gro_list.remove("bread")
gro_list
# Out:
# ['milk',
#  'curd',
#  'egg',
#  'butter',
#  'biscuits',
#  'chips',
#  'coffee',
#  'potatoes',
#  'onions',
#  'bread']

# %%
gro_list.pop()
# Out:
# 'bread'

# %%
gro_list
# Out:
# ['milk',
#  'curd',
#  'egg',
#  'butter',
#  'biscuits',
#  'chips',
#  'coffee',
#  'potatoes',
#  'onions']

# %%
gro_list.pop(2)
# Out:
# 'egg'

# %%
gro_list
# Out:
# ['milk', 'curd', 'butter', 'biscuits', 'chips', 'coffee', 'potatoes', 'onions']

# %%
gro_list.index("butter")
# Out:
# 2

# %%
gro_list.sort()
gro_list
# Out:
# ['biscuits', 'butter', 'chips', 'coffee', 'curd', 'milk', 'onions', 'potatoes']

# %%
gro_list.reverse()
gro_list
# Out:
# ['potatoes', 'onions', 'milk', 'curd', 'coffee', 'chips', 'butter', 'biscuits']

# %%
gro_list.remove("coffee")

gro_list
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-1355338524.py in <cell line: 0>()
# ----> 1 gro_list.remove("coffee")
#       2
#       3 gro_list
#
# ValueError: list.remove(x): x not in list

# %%
gro_list.remove("tea")
gro_list

# %%
gro_list[1] = "Ice Cream"
gro_list
# Out:
# ['potatoes', 'Ice Cream', 'milk', 'curd', 'chips', 'butter', 'biscuits']

# %%
#initial team list
team=["john" ,"anitha","meera","priya"]
team.append("arjun")
team.insert(1,"kiran")
team.remove("john")
index_priya=team.index("priya")
team.sort()
team.reverse()
back_upteam=team.copy()
print("backup team:" ,backup team)

# %%
gro_tuple=("milk" ,"curd" ,"coffee" ,"butter")
type(gro_tuple)
# Out:
# tuple

# %%
gro_tuple[1]
# Out:
# 'curd'

# %%
gro_tuple[-2]
# Out:
# 'coffee'

# %%
new_gro_list =list(gro_tuple)
new_gro_list
# Out:
# ['milk', 'curd', 'coffee', 'butter']

# %%
new_gro_list.append("biscuits")
new_gro_list
# Out:
# ['milk', 'curd', 'coffee', 'butter', 'biscuits']

# %%
gro_tuple=tuple(new_gro_list)
gro_tuple
# Out:
# ('milk', 'curd', 'coffee', 'butter', 'biscuits')
