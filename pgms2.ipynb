# %% [markdown]
# <a href="https://colab.research.google.com/github/silpa4h-crypto/LibraryManager/blob/main/pgms2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
car ={
    "brand":"ford",
    "model":"mustang" ,
    "year":2025,
    "cur_year":2025
}

car
# Out:
# {'brand': 'ford', 'model': 'mustang', 'year': 2025, 'cur_year': 2025}

# %%
print(len(car))
# Out:
# 4

# %%
type(car)
# Out:
# dict

# %%
employee =dict(name="anju",age=25,salary=50000)
employee
# Out:
# {'name': 'anju', 'age': 25, 'salary': 50000}

# %%
employee['name']
# Out:
# 'anju'

# %%
employee.get('salary')
# Out:
# 50000

# %%
x= employee.keys()
x
# Out:
# dict_keys(['name', 'age', 'salary'])

# %%
y=employee.values()
y
# Out:
# dict_values(['anju', 25, 50000])

# %%
employee['name']="swathi"
employee.values()
# Out:
# dict_values(['swathi', 25, 50000])

# %%
z=employee.items()
z
# Out:
# dict_items([('name', 'swathi'), ('age', 25), ('salary', 50000)])

# %%
type(z)
# Out:
# dict_items

# %%
employee.update({"salary":60000,"dept":"IT"})
employee
# Out:
# {'name': 'swathi', 'age': 25, 'salary': 60000, 'dept': 'IT'}

# %%
employee["place"]="Trivandrum"
employee
# Out:
# {'name': 'swathi',
#  'age': 25,
#  'salary': 60000,
#  'dept': 'IT',
#  'place': 'Trivandrum'}

# %%
employee["dummy"]=""

# %%
employee
# Out:
# {'name': 'swathi',
#  'age': 25,
#  'salary': 60000,
#  'dept': 'IT',
#  'place': 'Trivandrum',
#  'dummy': ''}

# %%
employee.popitem()
# Out:
# ('dept', 'IT')

# %%
employee.pop("place")

# %%
employee
# Out:
# {'name': 'swathi', 'age': 25, 'salary': 60000, 'dummy': ''}

# %%
del employee['place']
del employee

# %%
employee
# Out:
# {'name': 'swathi', 'age': 25, 'salary': 60000, 'dummy': ''}

# %%
employee.clear()

# %%
employee
# Out:
# {}

# %%
employee['fname']="anna"
employee['sname']="john"
employee['id']="emp101"
employee
# Out:
# {'fname': 'anna', 'sname': 'john', 'id': 'emp101'}

# %%
del employee['place']
del employee
employee.clear()

# %% [markdown]
# Nested Dictionary

# %%
employees={
    "emp1":{
        "name":"raj",
        "salary":50000,
        "dept":"IT"
    },
    "emp2":{
        "name":"manju",
        "salary":60000,
        "dept":"HR"
    },
    "emp3": {
        "name":"anju",
        "salary":70000,
        "dept":"Finance"
    }
}

# %%
employees={
    "emp1":{
            "name": "raj",
            "salary":50000,
            "dept":"IT"
            },

    "emp2":{
      "name":"manju",
        "salary":60000,
        "dept":"HR"
    },
    "emp3":{
        "name":"anju",
        "salary":70000,
        "dept":"Finance"
    }
}

# %%
employees.get('emp3')
employees["emp3"]
